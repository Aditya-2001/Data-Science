# %%
import pandas as pd

# %%
s=pd.Series([1,2,3,4,5])

# %%
s['d']
# Out:
# d    4
# d    5
# dtype: int64

# %%
s=pd.Series([1,2,3,4,5],index=['a','b','c','d','d'])

# %%
df=pd.DataFrame([[1,2,3,4],[5,6,7,8]])

# %%
df
# Out:
#    c  d  e  f
# a  1  2  3  4
# b  5  6  7  8

# %%
df=pd.DataFrame([[1,2,3,4],[5,6,7,8]],index=['a','b'],columns=['c','d','e','f'])

# %%
df['c']
# Out:
# a    1
# b    5
# Name: c, dtype: int64

# %%
df.loc['a']
# Out:
# c    1
# d    2
# e    3
# f    4
# Name: a, dtype: int64

# %%
 df.shape
# Out:
# (2, 4)

# %%
df.head()
# Out:
#    c  d  e  f
# a  1  2  3  4
# b  5  6  7  8

# %%
df.head(1)
# Out:
#    c  d  e  f
# a  1  2  3  4

# %%
df.count()
# Out:
# c    2
# d    2
# e    2
# f    2
# dtype: int64

# %%
df.count(axis=1)
# Out:
# a    4
# b    4
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, a to b
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   c       2 non-null      int64
#  1   d       2 non-null      int64
#  2   e       2 non-null      int64
#  3   f       2 non-null      int64
# dtypes: int64(4)
# memory usage: 188.0+ bytes

# %%
df.describe()
# Out:
#               c         d         e         f
# count  2.000000  2.000000  2.000000  2.000000
# mean   3.000000  4.000000  5.000000  6.000000
# std    2.828427  2.828427  2.828427  2.828427
# min    1.000000  2.000000  3.000000  4.000000
# 25%    2.000000  3.000000  4.000000  5.000000
# 50%    3.000000  4.000000  5.000000  6.000000
# 75%    4.000000  5.000000  6.000000  7.000000
# max    5.000000  6.000000  7.000000  8.000000

# %%
df=pd.DataFrame([{'a':1, 'b':2, 'c':3}, {'a': 3,'b': 6,'d': 7}])

# %%
df
# Out:
#    a  b  c
# 0  1  2  3
# 1  3  6  7

# %%
df=pd.DataFrame({'a':[1,2],'b':[3,4]})

# %%
df.isnull()
# Out:
#        a      b      c      d
# 0  False  False  False   True
# 1   True  False  False  False

# %%
df=pd.DataFrame([{'a':1, 'b':2, 'c':3}, {'c': 3,'b': 6,'d': 7}])

# %%
df.notnull()
# Out:
#        a     b     c      d
# 0   True  True  True  False
# 1  False  True  True   True

# %%
df1=df.dropna()

# %%
df1
# Out:
# Empty DataFrame
# Columns: [a, b, c, d]
# Index: []

# %%
df.dropna(inplace=True)

# %%
df
# Out:
# Empty DataFrame
# Columns: [a, b, c, d]
# Index: []

# %%
df.fillna(1)
# Out:
#      a  b  c    d
# 0  1.0  2  3  1.0
# 1  1.0  6  3  7.0

# %%
df=pd.DataFrame({'a':[1,2,3,4,5],'b':[3,4,4,5,6],'c':[1,2,3,2,1]})

# %%
df
# Out:
#    a  b  c
# 0  1  3  1
# 1  2  4  2
# 2  3  4  3
# 3  4  5  2
# 4  5  6  1

# %%
g=df.groupby('c')

# %%
g.size()
# Out:
# c
# 1    2
# 2    2
# 3    1
# dtype: int64

# %%
g.groups
# Out:
# {1: [0, 4], 2: [1, 3], 3: [2]}

# %%
g.get_group(1)
# Out:
#    a  b  c
# 0  1  3  1
# 4  5  6  1

# %%
g=df.groupby(['c','b'])

# %%
g.groups
# Out:
# {(1, 3): [0], (1, 6): [4], (2, 4): [1], (2, 5): [3], (3, 4): [2]}

# %%
g.get_group((1,3))
# Out:
#    a  b  c
# 0  1  3  1

# %%
df=pd.read_csv('raw_data19.csv')

# %%
import pandas as pd

# %%
df
# Out:
#        Entry_ID  State Patient Number Date Announced  Age Bracket Gender  \
# 0        376312                   NaN     13/11/2020          NaN    NaN
# 1        376313                   NaN     13/11/2020          NaN    NaN
# 2        376314                   NaN     13/11/2020          NaN    NaN
# 3        376315                   NaN     13/11/2020          NaN    NaN
# 4        376316                   NaN     13/11/2020          NaN    NaN
# ...         ...                   ...            ...          ...    ...
# 25379    402067                   NaN     21/11/2020          NaN    NaN
# 25380    402066                   NaN     24/11/2020          NaN    NaN
# 25381    402065                   NaN     25/11/2020          NaN    NaN
# 25382    402063                   NaN     28/11/2020          NaN    NaN
# 25383    402062                   NaN     30/11/2020          NaN    NaN
#
#       Detected City   Detected District Detected State State code  Num Cases  \
# ...

# %%
g=df.groupby('Current Status')

# %%
g.size()
# Out:
# Current Status
# Deceased           3567
# Hospitalized      11429
# Migrated_Other      149
# Recovered         10239
# dtype: int64

# %%
g=df.groupby('Detected State')

# %%
g.size()
# Out:
# Detected State
# Andaman and Nicobar Islands                   53
# Andhra Pradesh                               589
# Arunachal Pradesh                            393
# Assam                                         79
# Bihar                                       1366
# Chandigarh                                    60
# Chhattisgarh                                1147
# Dadra and Nagar Haveli and Daman and Diu      52
# Delhi                                         54
# Goa                                           53
# Gujarat                                     1162
# Haryana                                      958
# Himachal Pradesh                             543
# Jammu and Kashmir                            752
# Jharkhand                                    719
# Karnataka                                   1213
# Kerala                                       963
# Ladakh                                        73
# Madhya Pradesh                              1916
# ...

# %%
df
# Out:
#        Entry_ID  State Patient Number Date Announced  Age Bracket Gender  \
# 0        376312                   NaN     13/11/2020          NaN    NaN
# 1        376313                   NaN     13/11/2020          NaN    NaN
# 2        376314                   NaN     13/11/2020          NaN    NaN
# 3        376315                   NaN     13/11/2020          NaN    NaN
# 4        376316                   NaN     13/11/2020          NaN    NaN
# ...         ...                   ...            ...          ...    ...
# 25379    402067                   NaN     21/11/2020          NaN    NaN
# 25380    402066                   NaN     24/11/2020          NaN    NaN
# 25381    402065                   NaN     25/11/2020          NaN    NaN
# 25382    402063                   NaN     28/11/2020          NaN    NaN
# 25383    402062                   NaN     30/11/2020          NaN    NaN
#
#       Detected City   Detected District Detected State State code  Num Cases  \
# ...

# %%
g=df.groupby('Gender')

# %%
g.size()
# Out:
# Gender
# F     98
# M    296
# dtype: int64

# %%
g.get_group()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-0452a134c3f5> in <module>
# ----> 1 g.get_group('')
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in get_group(self, name, obj)
#     843         inds = self._get_index(name)
#     844         if not len(inds):
# --> 845             raise KeyError(name)
#     846
#     847         return obj._take_with_is_copy(inds, axis=self.axis)
#
# KeyError: ''

# %%
df
# Out:
#        Entry_ID  State Patient Number Date Announced  Age Bracket Gender  \
# 0        376312                   NaN     13/11/2020          NaN    NaN
# 1        376313                   NaN     13/11/2020          NaN    NaN
# 2        376314                   NaN     13/11/2020          NaN    NaN
# 3        376315                   NaN     13/11/2020          NaN    NaN
# 4        376316                   NaN     13/11/2020          NaN    NaN
# ...         ...                   ...            ...          ...    ...
# 25379    402067                   NaN     21/11/2020          NaN    NaN
# 25380    402066                   NaN     24/11/2020          NaN    NaN
# 25381    402065                   NaN     25/11/2020          NaN    NaN
# 25382    402063                   NaN     28/11/2020          NaN    NaN
# 25383    402062                   NaN     30/11/2020          NaN    NaN
#
#       Detected City   Detected District Detected State State code  Num Cases  \
# ...

# %%
g=df.isnull().groupby(["Gender"])

# %%
g.size()
# Out:
# Gender
# False      394
# True     24990
# dtype: int64
